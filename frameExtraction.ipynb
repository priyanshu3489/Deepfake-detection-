# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshu3489/Deepfake-detection-/blob/main/frameExtraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import os

def extract_frames(video_path, output_folder, sampling_rate=2, motion_threshold=30):
    # Ensure output directory exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Capture the video from file
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error opening video file {video_path}")
        return

    # Get video file name for naming frames
    video_name = os.path.basename(video_path).split('.')[0]

    # Read the first frame
    ret, prev_frame = cap.read()
    if not ret:
        print(f"Error reading the first frame from {video_path}")
        return

    frame_count = 0
    saved_frame_count = 0
    while True:
        # Read frame by frame
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1

        # Sample frames based on the sampling rate
        if frame_count % sampling_rate == 0:
            # Calculate the absolute difference between current frame and previous frame
            gray_prev = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
            gray_curr = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            diff = cv2.absdiff(gray_prev, gray_curr)

            # Apply threshold to the difference
            _, thresh = cv2.threshold(diff, motion_threshold, 255, cv2.THRESH_BINARY)

            # Check if there is any significant motion
            motion_detected = cv2.countNonZero(thresh) > 0

            if motion_detected:
                frame_filename = f"{video_name}_frame_{saved_frame_count:04d}.jpg"
                cv2.imwrite(os.path.join(output_folder, frame_filename), frame)
                saved_frame_count += 1

            # Update previous frame
            prev_frame = frame

    cap.release()
    print(f"Extracted {saved_frame_count} frames from {video_path}")

def process_videos(input_folder, output_folder, sampling_rate=5, motion_threshold=30):
    # Get list of all video files in the input directory
    video_files = [f for f in os.listdir(input_folder) if f.endswith(('.mp4', '.avi', '.mov'))]

    for video_file in video_files:
        video_path = os.path.join(input_folder, video_file)
        extract_frames(video_path, output_folder, sampling_rate, motion_threshold)

# %%
# Set the input and output folder paths
input_folder = '/content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real'
output_folder = '/content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real_frame'

# %%
# Call the function to process all videos in the input folder
process_videos(input_folder, output_folder, sampling_rate=2, motion_threshold=30)
# Out:
# Extracted 243 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00002.mp4
# Extracted 167 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00001.mp4
# Extracted 209 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00000.mp4
# Extracted 231 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00005.mp4
# Extracted 172 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00011.mp4
# Extracted 214 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00004.mp4
# Extracted 229 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00007.mp4
# Extracted 142 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00003.mp4
# Extracted 191 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00010.mp4
# Extracted 231 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00006.mp4
# Extracted 283 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00009.mp4
# Extracted 229 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00008.mp4
# Extracted 202 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00019.mp4
# Extracted 191 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00012.mp4
# Extracted 227 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00013.mp4
# Extracted 225 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00020.mp4
# Extracted 197 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00018.mp4
# Extracted 149 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00016.mp4
# Extracted 217 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00015.mp4
# Extracted 229 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00014.mp4
# Extracted 132 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00017.mp4
# Extracted 217 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00021.mp4
# Extracted 235 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00022.mp4
# Extracted 248 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00026.mp4
# Extracted 232 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00027.mp4
# Extracted 194 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00029.mp4
# Extracted 231 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00023.mp4
# Extracted 203 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00030.mp4
# Extracted 229 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00028.mp4
# Extracted 215 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00025.mp4
# Extracted 266 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00024.mp4
# Extracted 221 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00038.mp4
# Extracted 201 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00037.mp4
# Extracted 198 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00032.mp4
# Extracted 251 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00031.mp4
# Extracted 220 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00035.mp4
# Extracted 230 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00034.mp4
# Extracted 218 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00039.mp4
# Extracted 234 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00036.mp4
# Extracted 188 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00041.mp4
# Extracted 184 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00040.mp4
# Extracted 182 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00033.mp4
# Extracted 172 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00043.mp4
# Extracted 222 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00050.mp4
# Extracted 184 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00042.mp4
# Extracted 150 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00048.mp4
# Extracted 224 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00046.mp4
# Extracted 244 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00047.mp4
# Extracted 221 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00049.mp4
# Extracted 189 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00044.mp4
# Extracted 198 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00045.mp4
# Extracted 171 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00051.mp4
# Extracted 230 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00053.mp4
# Extracted 209 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00052.mp4
# Extracted 232 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00057.mp4
# Extracted 205 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00055.mp4
# Extracted 236 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00060.mp4
# Extracted 193 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00054.mp4
# Extracted 204 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00061.mp4
# Extracted 263 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00056.mp4
# Extracted 231 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00058.mp4
# Extracted 193 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00059.mp4
# Extracted 128 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00063.mp4
# Extracted 189 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00066.mp4
# Extracted 214 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00064.mp4
# Extracted 228 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00062.mp4
# Extracted 230 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00067.mp4
# Extracted 154 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00068.mp4
# Extracted 246 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00065.mp4
# Extracted 207 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00069.mp4
# Extracted 212 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00072.mp4
# Extracted 196 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00074.mp4
# Extracted 224 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00073.mp4
# Extracted 172 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00070.mp4
# Extracted 222 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00071.mp4
# Extracted 237 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00076.mp4
# Extracted 238 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00080.mp4
# Extracted 218 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00075.mp4
# Extracted 228 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00077.mp4
# Extracted 224 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00078.mp4
# Extracted 215 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00081.mp4
# Extracted 192 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00079.mp4
# Extracted 192 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00084.mp4
# Extracted 240 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00086.mp4
# Extracted 220 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00082.mp4
# Extracted 227 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00087.mp4
# Extracted 234 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00088.mp4
# Extracted 291 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00085.mp4
# Extracted 165 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00083.mp4
# Extracted 202 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00094.mp4
# Extracted 203 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00090.mp4
# Extracted 148 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00096.mp4
# Extracted 208 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00091.mp4
# Extracted 250 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00097.mp4
# Extracted 236 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00089.mp4
# Extracted 259 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00092.mp4
# Extracted 233 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00095.mp4
# Extracted 210 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00093.mp4
# Extracted 209 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00101.mp4
# Extracted 224 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00098.mp4
# Extracted 226 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00102.mp4
# Extracted 265 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00100.mp4
# Extracted 241 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00099.mp4
# Extracted 238 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00105.mp4
# Extracted 249 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00104.mp4
# Extracted 219 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00103.mp4
# Extracted 125 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00109.mp4
# Extracted 157 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00112.mp4
# Extracted 220 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00108.mp4
# Extracted 225 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00110.mp4
# Extracted 178 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00111.mp4
# Extracted 154 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00114.mp4
# Extracted 228 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00107.mp4
# Extracted 236 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00113.mp4
# Extracted 155 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00115.mp4
# Extracted 163 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00106.mp4
# Extracted 138 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00123.mp4
# Extracted 229 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00117.mp4
# Extracted 233 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00120.mp4
# Extracted 177 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00119.mp4
# Extracted 226 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00116.mp4
# Extracted 230 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00118.mp4
# Extracted 154 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00121.mp4
# Extracted 134 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00122.mp4
# Extracted 164 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00124.mp4
# Extracted 233 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00127.mp4
# Extracted 154 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00131.mp4
# Extracted 222 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00128.mp4
# Extracted 190 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00130.mp4
# Extracted 122 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00125.mp4
# Extracted 150 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00126.mp4
# Extracted 170 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00132.mp4
# Extracted 185 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00129.mp4
# Extracted 214 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00141.mp4
# Extracted 107 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00136.mp4
# Extracted 208 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00139.mp4
# Extracted 166 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00134.mp4
# Extracted 176 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00135.mp4
# Extracted 172 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00137.mp4
# Extracted 209 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00133.mp4
# Extracted 172 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00140.mp4
# Extracted 150 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00142.mp4
# Extracted 215 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00138.mp4
# Extracted 227 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00143.mp4
# Extracted 225 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00144.mp4
# Extracted 212 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00148.mp4
# Extracted 235 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00147.mp4
# Extracted 153 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00151.mp4
# Extracted 242 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00149.mp4
# Extracted 193 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00145.mp4
# Extracted 298 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00146.mp4
# Extracted 222 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00150.mp4
# Extracted 173 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00154.mp4
# Extracted 220 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00158.mp4
# Extracted 223 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00157.mp4
# Extracted 285 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00155.mp4
# Extracted 153 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00156.mp4
# Extracted 348 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00152.mp4
# Extracted 241 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00153.mp4
# Extracted 178 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00159.mp4
# Extracted 245 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00164.mp4
# Extracted 233 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00160.mp4
# Extracted 255 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00161.mp4
# Extracted 220 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00162.mp4
# Extracted 230 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00165.mp4
# Extracted 195 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00166.mp4
# Extracted 135 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00163.mp4
# Extracted 167 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00172.mp4
# Extracted 236 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00167.mp4
# Extracted 225 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00168.mp4
# Extracted 140 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00173.mp4
# Extracted 217 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00171.mp4
# Extracted 230 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00175.mp4
# Extracted 204 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00169.mp4
# Extracted 151 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00170.mp4
# Extracted 197 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00174.mp4
# Extracted 298 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00176.mp4
# Extracted 237 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00183.mp4
# Extracted 198 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00184.mp4
# Extracted 193 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00181.mp4
# Extracted 223 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00179.mp4
# Extracted 259 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00177.mp4
# Extracted 227 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00182.mp4
# Extracted 147 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00180.mp4
# Extracted 133 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00178.mp4
# Extracted 199 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00189.mp4
# Extracted 219 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00191.mp4
# Extracted 254 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00186.mp4
# Extracted 224 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00187.mp4
# Extracted 235 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00185.mp4
# Extracted 175 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00193.mp4
# Extracted 227 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00192.mp4
# Extracted 220 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00188.mp4
# Extracted 226 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00190.mp4
# Extracted 164 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00201.mp4
# Extracted 239 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00199.mp4
# Extracted 176 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00200.mp4
# Extracted 240 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00195.mp4
# Extracted 199 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00198.mp4
# Extracted 230 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00194.mp4
# Extracted 227 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00197.mp4
# Extracted 239 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00196.mp4
# Extracted 224 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00206.mp4
# Extracted 58 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00207.mp4
# Extracted 153 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00203.mp4
# Extracted 218 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00205.mp4
# Extracted 97 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00210.mp4
# Extracted 223 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00209.mp4
# Extracted 226 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00208.mp4
# Extracted 248 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00202.mp4
# Extracted 229 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00204.mp4
# Extracted 215 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00219.mp4
# Extracted 183 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00213.mp4
# Extracted 218 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00220.mp4
# Extracted 230 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00218.mp4
# Extracted 208 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00211.mp4
# Extracted 222 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00214.mp4
# Extracted 161 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00215.mp4
# Extracted 184 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00216.mp4
# Extracted 197 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00212.mp4
# Extracted 151 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00217.mp4
# Extracted 223 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00221.mp4
# Extracted 233 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00222.mp4
# Extracted 230 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00223.mp4
# Extracted 154 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00224.mp4
# Extracted 230 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00225.mp4
# Extracted 223 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00228.mp4
# Extracted 217 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00226.mp4
# Extracted 235 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00227.mp4
# Extracted 244 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00235.mp4
# Extracted 193 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00229.mp4
# Extracted 214 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00236.mp4
# Extracted 184 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00232.mp4
# Extracted 226 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00233.mp4
# Extracted 176 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00231.mp4
# Extracted 212 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00237.mp4
# Extracted 179 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00234.mp4
# Extracted 169 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00238.mp4
# Extracted 226 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00230.mp4
# Extracted 210 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00242.mp4
# Extracted 209 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00240.mp4
# Extracted 242 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00239.mp4
# Extracted 225 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00243.mp4
# Extracted 201 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00246.mp4
# Extracted 211 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00241.mp4
# Extracted 128 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00244.mp4
# Extracted 231 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00245.mp4
# Extracted 239 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00248.mp4
# Extracted 226 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00247.mp4
# Extracted 236 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/00249.mp4
# Extracted 236 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id0_0003.mp4
# Extracted 198 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id0_0000.mp4
# Extracted 138 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id0_0001.mp4
# Extracted 156 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id0_0004.mp4
# Extracted 129 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id0_0002.mp4
# Extracted 231 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id0_0008.mp4
# Extracted 172 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id0_0006.mp4
# Extracted 222 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id10_0004.mp4
# Extracted 35 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id10_0001.mp4
# Extracted 191 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id0_0007.mp4
# Extracted 134 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id10_0002.mp4
# Extracted 135 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id10_0005.mp4
# Extracted 80 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id10_0006.mp4
# Extracted 222 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id0_0005.mp4
# Extracted 229 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id0_0009.mp4
# Extracted 146 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id10_0003.mp4
# Extracted 119 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id10_0000.mp4
# Extracted 159 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id11_0000.mp4
# Extracted 209 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id10_0007.mp4
# Extracted 145 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id11_0008.mp4
# Extracted 153 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id11_0003.mp4
# Extracted 154 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id11_0007.mp4
# Extracted 165 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id11_0002.mp4
# Extracted 202 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id11_0001.mp4
# Extracted 144 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id11_0004.mp4
# Extracted 126 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id11_0006.mp4
# Extracted 249 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id10_0009.mp4
# Extracted 95 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id10_0008.mp4
# Extracted 160 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id11_0005.mp4
# Extracted 112 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id12_0003.mp4
# Extracted 136 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id11_0009.mp4
# Extracted 191 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id12_0001.mp4
# Extracted 123 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0001.mp4
# Extracted 103 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0000.mp4
# Extracted 153 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id12_0006.mp4
# Extracted 138 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id12_0004.mp4
# Extracted 37 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id12_0000.mp4
# Extracted 140 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id11_0010.mp4
# Extracted 167 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id12_0002.mp4
# Extracted 149 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id12_0005.mp4
# Extracted 178 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0012.mp4
# Extracted 182 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0008.mp4
# Extracted 159 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0003.mp4
# Extracted 111 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0007.mp4
# Extracted 204 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0011.mp4
# Extracted 108 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0004.mp4
# Extracted 80 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0010.mp4
# Extracted 119 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0005.mp4
# Extracted 152 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0009.mp4
# Extracted 157 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0006.mp4
# Extracted 165 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0002.mp4
# Extracted 139 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id16_0001.mp4
# Extracted 177 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0014.mp4
# Extracted 139 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id16_0002.mp4
# Extracted 129 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id16_0003.mp4
# Extracted 132 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id16_0007.mp4
# Extracted 132 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id16_0005.mp4
# Extracted 150 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id16_0000.mp4
# Extracted 168 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0013.mp4
# Extracted 142 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id16_0008.mp4
# Extracted 187 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id16_0004.mp4
# Extracted 96 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id16_0006.mp4
# Extracted 189 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id13_0015.mp4
# Extracted 86 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id17_0003.mp4
# Extracted 97 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id17_0006.mp4
# Extracted 116 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id16_0010.mp4
# Extracted 143 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id17_0002.mp4
# Extracted 148 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id17_0005.mp4
# Extracted 142 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id16_0009.mp4
# Extracted 142 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id17_0000.mp4
# Extracted 112 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id16_0012.mp4
# Extracted 139 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id17_0004.mp4
# Extracted 139 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id17_0001.mp4
# Extracted 126 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id16_0011.mp4
# Extracted 127 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id16_0013.mp4
# Extracted 210 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id1_0005.mp4
# Extracted 103 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id1_0001.mp4
# Extracted 171 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id1_0004.mp4
# Extracted 203 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id1_0009.mp4
# Extracted 125 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id17_0008.mp4
# Extracted 151 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id1_0006.mp4
# Extracted 216 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id1_0003.mp4
# Extracted 28 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id1_0007.mp4
# Extracted 208 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id1_0008.mp4
# Extracted 117 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id17_0009.mp4
# Extracted 115 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id17_0007.mp4
# Extracted 180 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id1_0002.mp4
# Extracted 176 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id1_0000.mp4
# Extracted 202 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id2_0000.mp4
# Extracted 164 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id2_0002.mp4
# Extracted 140 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id2_0009.mp4
# Extracted 185 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id3_0001.mp4
# Extracted 182 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id2_0006.mp4
# Extracted 253 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id2_0008.mp4
# Extracted 142 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id2_0003.mp4
# Extracted 219 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id2_0007.mp4
# Extracted 210 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id3_0000.mp4
# Extracted 163 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id2_0004.mp4
# Extracted 119 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id2_0005.mp4
# Extracted 209 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id3_0002.mp4
# Extracted 146 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id2_0001.mp4
# Extracted 206 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id3_0008.mp4
# Extracted 208 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id3_0009.mp4
# Extracted 218 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id4_0004.mp4
# Extracted 192 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id3_0005.mp4
# Extracted 170 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id3_0007.mp4
# Extracted 193 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id3_0004.mp4
# Extracted 205 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id4_0002.mp4
# Extracted 202 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id4_0000.mp4
# Extracted 183 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id3_0003.mp4
# Extracted 183 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id4_0003.mp4
# Extracted 177 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id3_0006.mp4
# Extracted 207 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id4_0001.mp4
# Extracted 172 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id6_0002.mp4
# Extracted 185 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id6_0003.mp4
# Extracted 152 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id4_0008.mp4
# Extracted 139 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id6_0001.mp4
# Extracted 196 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id4_0007.mp4
# Extracted 149 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id4_0006.mp4
# Extracted 218 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id4_0009.mp4
# Extracted 206 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id4_0005.mp4
# Extracted 175 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id6_0005.mp4
# Extracted 280 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id6_0000.mp4
# Extracted 224 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id6_0004.mp4
# Extracted 261 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id6_0007.mp4
# Extracted 259 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id7_0004.mp4
# Extracted 133 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id6_0006.mp4
# Extracted 68 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id7_0005.mp4
# Extracted 147 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id7_0001.mp4
# Extracted 128 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id7_0002.mp4
# Extracted 117 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id6_0008.mp4
# Extracted 277 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id7_0003.mp4
# Extracted 133 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id7_0000.mp4
# Extracted 224 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id6_0009.mp4
# Extracted 106 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id7_0006.mp4
# Extracted 256 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id8_0002.mp4
# Extracted 250 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id8_0006.mp4
# Extracted 219 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id7_0009.mp4
# Extracted 180 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id8_0007.mp4
# Extracted 194 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id7_0007.mp4
# Extracted 270 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id8_0004.mp4
# Extracted 183 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id8_0003.mp4
# Extracted 106 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id8_0005.mp4
# Extracted 172 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id8_0001.mp4
# Extracted 127 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id7_0008.mp4
# Extracted 217 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id8_0000.mp4
# Extracted 208 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id9_0000.mp4
# Extracted 204 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id9_0001.mp4
# Extracted 204 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id9_0005.mp4
# Extracted 179 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id9_0004.mp4
# Extracted 200 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id9_0006.mp4
# Extracted 264 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id8_0008.mp4
# Extracted 193 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id9_0003.mp4
# Extracted 202 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id9_0007.mp4
# Extracted 160 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id9_0002.mp4
# Extracted 185 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id8_0009.mp4
# Extracted 229 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id9_0008.mp4
# Extracted 136 frames from /content/drive/MyDrive/Colab Notebooks (1)/Celeb-DF/real/id9_0009.mp4
